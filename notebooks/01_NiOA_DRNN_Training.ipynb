# %% [markdown]
# # NiOA-DRNN — Multi-Horizon Auto-Loop Training
#
# **Author** : Anwesha Singh
# **Dept.**   : Computer Science Engineering, Manipal University Jaipur
#
# ---
#
# ## How to use
#
# | Cell | What to do |
# |---|---|
# | **Cell 1** | Run once per kernel session |
# | **Cell 2** | Set `HORIZONS_TO_RUN` — then never touch again |
# | **Cell 3** | Run and walk away — all horizons train automatically |
# | **Cell 4** | Run after Cell 3 to print the cross-horizon table |
#
# ## Why GPU works now (important for your report)
#
# Your training set is **(1,874,617 × 120 × 17) float32 ≈ 15 GB**.
# Two standard approaches fail at this scale:
#
# - `model.fit(X_train, y_train)` — Keras converts the entire 15 GB numpy array
#   into a GPU-resident EagerTensor before the first batch runs → OOM crash.
# - `tf.data.Dataset.from_tensor_slices((X, y))` — same problem; the full
#   array becomes a graph constant in GPU memory → crash.
#
# The correct solution is **`tf.keras.utils.Sequence`** (`SequenceDataGenerator`
# in `core/utils.py`).  Keras calls `__getitem__(i)` to fetch one numpy batch
# (32 × 120 × 17 ≈ 1.3 MB) and converts only **that batch** to a GPU tensor.
# The 15 GB array never leaves CPU RAM as a whole.  Peak GPU usage = one batch.

# %% [markdown]
# ## Cell 1 — Imports and Environment

# %%
import os, sys, json, gc, time
import numpy as np
import pandas as pd
import matplotlib
matplotlib.use('Agg')
import matplotlib.pyplot as plt
import seaborn as sns
import joblib
import tensorflow as tf
import tensorflow.keras.backend as K
from datetime import datetime
from tensorflow.keras.callbacks import EarlyStopping

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), '..'))
for _p in [PROJECT_ROOT, os.path.join(PROJECT_ROOT, 'core')]:
    if _p not in sys.path:
        sys.path.insert(0, _p)

from core.config import (
    DATA_PATH, SPLITS_DIR, NIOA_RESULTS_DIR, RESULTS_DIR,
    FORECAST_HORIZONS, SEQUENCE_LENGTH, TRAIN_RATIO, VAL_RATIO,
    RANDOM_SEED, N_AGENTS, MAX_ITERATIONS, EXPLORATION_FACTOR,
    EXPLOITATION_FACTOR, OPT_SUBSET_RATIO, OPT_EPOCHS, OPT_PATIENCE,
    OPT_TIME_LIMIT, FINAL_EPOCHS, FINAL_PATIENCE, HYPERPARAMETER_BOUNDS,
    GAP_TOLERANCE_FACTOR,
    # v2 additions — target transform and loss configuration
    TARGET_CAP_PERCENTILE, TARGET_LOG_TRANSFORM,
    LOSS_FUNCTION, HUBER_DELTA,
)
from core.utils import (
    set_seeds, configure_gpu, scale_numeric_features,
    create_sequences, to_python_types, SequenceDataGenerator,
)
from core.preprocessing import load_and_prepare_data, split_by_timestamp
from core.models        import NinjaOptimizationAlgorithm, create_lstm_model
from core.train         import objective_function_lstm
from core.evaluate      import evaluate_keras_model

configure_gpu()
set_seeds(RANDOM_SEED)
sns.set(style='whitegrid')

ANALYSIS_DIR = os.path.join(RESULTS_DIR, 'analysis')
os.makedirs(ANALYSIS_DIR, exist_ok=True)

print(f'TensorFlow        : {tf.__version__}')
print(f'Project root      : {PROJECT_ROOT}')
print(f'Target cap pctile : {TARGET_CAP_PERCENTILE}')
print(f'Log1p transform   : {TARGET_LOG_TRANSFORM}')
print(f'Loss function     : {LOSS_FUNCTION}  (delta={HUBER_DELTA})')
print(f'NiOA time limit   : {OPT_TIME_LIMIT} s per trial')
gpus = tf.config.list_physical_devices('GPU')
print(f'GPU(s) found      : {len(gpus)}  →  {[g.name for g in gpus]}')
# Out:
# GPU ready — 1 device(s), memory growth enabled.
# TensorFlow        : 2.10.1
# Project root      : D:\pipeline5_2
# Target cap pctile : 99.5
# Log1p transform   : True
# Loss function     : huber  (delta=1.0)
# NiOA time limit   : 1800 s per trial
# GPU(s) found      : 1  →  ['/physical_device:GPU:0']

# %% [markdown]
# ## Cell 2 — Select Horizons
# Edit `HORIZONS_TO_RUN` once.  Then run Cell 3 and do not touch this notebook again.

# %%
# ── Only edit these two lines ────────────────────────────────────────────────
HORIZONS_TO_RUN = [60, 300, 900, 1800]
SKIP_COMPLETED  = False
# ────────────────────────────────────────────────────────────────────────────

FINAL_BATCH_SIZE = 16

for _h in HORIZONS_TO_RUN:
    assert _h in FORECAST_HORIZONS, f'{_h} not in {FORECAST_HORIZONS}'

print(f'Horizons to train     : {HORIZONS_TO_RUN}')
print(f'Batch size            : {FINAL_BATCH_SIZE}')
print(f'Skip completed        : {SKIP_COMPLETED}')
print(f'Target cap percentile : {TARGET_CAP_PERCENTILE}')
print(f'log1p transform       : {TARGET_LOG_TRANSFORM}')
print(f'Loss function         : {LOSS_FUNCTION}')
print(f'NiOA trial time limit : {OPT_TIME_LIMIT} s')
# Out:
# Horizons to train     : [60, 300, 900, 1800]
# Batch size            : 16
# Skip completed        : False
# Target cap percentile : 99.5
# log1p transform       : True
# Loss function         : huber
# NiOA trial time limit : 1800 s

# %% [markdown]
# ## Cell 3 — Full Pipeline Loop
#
# For each horizon this cell runs:
#
# ```
#  3a  Load + gap-aware preprocess
#  3b  Chronological split (train 70% / val 15% / test 15%) + leakage check
#  3c  Feature scaling (train-only scaler) + stride-trick sequence generation
#  3d  Save canonical splits  →  results/splits/horizon_{k}/
#  3e  NiOA hyperparameter search on 30% subset via SequenceDataGenerator
#  3f  Final model training on full train split via SequenceDataGenerator
#  3g  Save model (.h5), scaler, training_config.json
#  3h  Evaluate on held-out test set, save metrics.json + predictions
#  3i  Save 5 publication plots  →  results/nioa_drnn/k{k}_*/plots/
#      GPU cleared before next horizon
# ```

# %%
all_results = {}
loop_start  = time.time()

for _loop_idx, HORIZON in enumerate(HORIZONS_TO_RUN):

    _elapsed = (time.time() - loop_start) / 3600
    print('\\n' + '=' * 65)
    print(f'  Horizon {_loop_idx+1}/{len(HORIZONS_TO_RUN)} : '
      f'k = {HORIZON} s   {datetime.now().strftime("%H:%M:%S")}   '
      f'{_elapsed:.2f} h elapsed')
    print('=' * 65)

    if SKIP_COMPLETED and os.path.isdir(NIOA_RESULTS_DIR):
        _done = [
            d for d in os.listdir(NIOA_RESULTS_DIR)
            if d.startswith(f'k{HORIZON}_') and
            os.path.isfile(os.path.join(
                NIOA_RESULTS_DIR, d, 'model', f'NiOA_DRNN_k{HORIZON}.h5'
            ))
        ]
        if _done:
            print(f'  [SKIP]  model already saved in {_done[-1]}')
            continue

    # ── 3a. Load + preprocess ────────────────────────────────────────────
    # v2: pass target_cap_percentile and log_transform from config
    print(f'\\n[3a] Preprocessing  '
          f'(k={HORIZON}s, gap={GAP_TOLERANCE_FACTOR}x, '
          f'cap={TARGET_CAP_PERCENTILE}th pctile, '
          f'log1p={TARGET_LOG_TRANSFORM})')

    df = load_and_prepare_data(
        DATA_PATH,
        k                     = HORIZON,
        gap_factor            = GAP_TOLERANCE_FACTOR,
        target_cap_percentile = TARGET_CAP_PERCENTILE,
        log_transform         = TARGET_LOG_TRANSFORM,
        verbose               = True,
    )

    # ── 3b. Split ────────────────────────────────────────────────────────
    print('[3b] Splitting')
    t_tr  = df['server_timestamp'].quantile(TRAIN_RATIO)
    t_va  = df['server_timestamp'].quantile(TRAIN_RATIO + VAL_RATIO)
    train_df, val_df, test_df = split_by_timestamp(df, t_tr, t_va)

    assert train_df['server_timestamp'].max() < val_df['server_timestamp'].min()
    assert val_df['server_timestamp'].max()   < test_df['server_timestamp'].min()

    print(f'  train {len(train_df):>9,}  val {len(val_df):>9,}  '
          f'test {len(test_df):>9,}  — no leakage')

    # ── 3c. Scale + sequences ────────────────────────────────────────────
    print('[3c] Scaling + sequence generation')
    TARGET       = 'energy_delta_k'
    feature_cols = [
        c for c in train_df.columns
        if c not in ['server_timestamp', 'energy', TARGET]
    ]

    X_tr_sc, X_va_sc, X_te_sc, scaler = scale_numeric_features(
        train_df[feature_cols].copy(),
        val_df[feature_cols].copy(),
        test_df[feature_cols].copy(),
        feature_cols,
    )

    X_train_seq, y_train_seq = create_sequences(
        X_tr_sc.values, train_df[TARGET].values, SEQUENCE_LENGTH)
    X_val_seq,   y_val_seq   = create_sequences(
        X_va_sc.values, val_df[TARGET].values,   SEQUENCE_LENGTH)
    X_test_seq,  y_test_seq  = create_sequences(
        X_te_sc.values, test_df[TARGET].values,  SEQUENCE_LENGTH)

    SEQ_LEN   = X_train_seq.shape[1]
    NUM_FEATS = X_train_seq.shape[2]

    print(f'  features ({len(feature_cols)}): {feature_cols}')
    print(f'  X_train {X_train_seq.shape}  '
          f'X_val {X_val_seq.shape}  '
          f'X_test {X_test_seq.shape}')
    print(f'  RAM (train seq) ≈ '
          f'{X_train_seq.nbytes / 1e9:.2f} GB   '
          f'GPU per batch ≈ '
          f'{FINAL_BATCH_SIZE * SEQ_LEN * NUM_FEATS * 4 / 1e6:.1f} MB')

    del df, train_df, val_df, test_df, X_tr_sc, X_va_sc, X_te_sc
    gc.collect()

    # ── 3d. Save canonical splits ────────────────────────────────────────
    print('[3d] Saving canonical splits')
    _sdir = os.path.join(SPLITS_DIR, f'horizon_{HORIZON}')
    os.makedirs(_sdir, exist_ok=True)

    np.save(os.path.join(_sdir, 'X_train.npy'), X_train_seq)
    np.save(os.path.join(_sdir, 'y_train.npy'), y_train_seq)
    np.save(os.path.join(_sdir, 'X_val.npy'),   X_val_seq)
    np.save(os.path.join(_sdir, 'y_val.npy'),   y_val_seq)
    np.save(os.path.join(_sdir, 'X_test.npy'),  X_test_seq)
    np.save(os.path.join(_sdir, 'y_test.npy'),  y_test_seq)
    joblib.dump(scaler, os.path.join(_sdir, 'scaler.pkl'))

    with open(os.path.join(_sdir, 'feature_cols.json'), 'w') as _f:
        json.dump(feature_cols, _f, indent=2)
    with open(os.path.join(_sdir, 'split_metadata.json'), 'w') as _f:
        json.dump({
            'horizon_k'              : HORIZON,
            'sequence_length'        : SEQUENCE_LENGTH,
            'gap_tolerance'          : GAP_TOLERANCE_FACTOR,
            'target_cap_percentile'  : TARGET_CAP_PERCENTILE,
            'log_transform'          : TARGET_LOG_TRANSFORM,
            'loss_function'          : LOSS_FUNCTION,
            'huber_delta'            : HUBER_DELTA,
            'train_ratio'            : TRAIN_RATIO,
            'val_ratio'              : VAL_RATIO,
            'n_train_sequences'      : int(len(X_train_seq)),
            'n_val_sequences'        : int(len(X_val_seq)),
            'n_test_sequences'       : int(len(X_test_seq)),
            'n_features'             : int(NUM_FEATS),
            'random_seed'            : RANDOM_SEED,
            'generated_at'           : datetime.now().isoformat(),
        }, _f, indent=2)
    print(f'  splits → {_sdir}')

    # ── 3e. NiOA hyperparameter optimisation ─────────────────────────────
    print(f'[3e] NiOA optimisation  '
          f'(agents={N_AGENTS}  iter={MAX_ITERATIONS}  '
          f'subset={int(OPT_SUBSET_RATIO*100)}%  '
          f'limit={OPT_TIME_LIMIT}s/trial  '
          f'loss={LOSS_FUNCTION})')

    _n_tr = int(len(X_train_seq) * OPT_SUBSET_RATIO)
    _n_va = int(len(X_val_seq)   * OPT_SUBSET_RATIO)

    _Xtr = X_train_seq[:_n_tr].copy()
    _ytr = y_train_seq[:_n_tr].copy()
    _Xva = X_val_seq[:_n_va].copy()
    _yva = y_val_seq[:_n_va].copy()

    # v2: pass loss configuration to objective function
    def _objective(p,
                   Xtr=_Xtr, ytr=_ytr,
                   Xva=_Xva, yva=_yva):
        return objective_function_lstm(
            p, Xtr, ytr, Xva, yva,
            opt_epochs  = OPT_EPOCHS,
            opt_patience = OPT_PATIENCE,
            time_limit  = OPT_TIME_LIMIT,
            loss_fn     = LOSS_FUNCTION,
            huber_delta = HUBER_DELTA,
        )

    ninja = NinjaOptimizationAlgorithm(
        objective_function  = _objective,
        bounds              = HYPERPARAMETER_BOUNDS,
        n_agents            = N_AGENTS,
        max_iterations      = MAX_ITERATIONS,
        exploration_factor  = EXPLORATION_FACTOR,
        exploitation_factor = EXPLOITATION_FACTOR,
        verbose             = True,
    )
    best_params, best_loss, convergence = ninja.optimize()

    print(f'  Best NiOA val loss : {best_loss:.8f}')
    print(f'  Best params : {best_params}')

    del ninja, _Xtr, _ytr, _Xva, _yva
    gc.collect()

    # ── 3f. Experiment directory ─────────────────────────────────────────
    _ts     = datetime.now().strftime('%Y%m%d_%H%M%S')
    exp_dir = os.path.join(
        NIOA_RESULTS_DIR, f'k{HORIZON}_seq{SEQUENCE_LENGTH}_{_ts}'
    )
    for _sub in ['model', 'predictions', 'plots']:
        os.makedirs(os.path.join(exp_dir, _sub), exist_ok=True)

    with open(os.path.join(exp_dir, 'best_params.json'), 'w') as _f:
        json.dump(to_python_types(best_params), _f, indent=4)
    np.save(os.path.join(exp_dir, 'convergence.npy'), np.array(convergence))

    # ── 3f (cont). Final model training ──────────────────────────────────
    # v2: pass loss_fn and huber_delta to create_lstm_model
    print(f'[3f] Final training  '
          f'(batch={FINAL_BATCH_SIZE}  epochs={FINAL_EPOCHS}  '
          f'patience={FINAL_PATIENCE}  loss={LOSS_FUNCTION})')
    K.clear_session()
    gc.collect()

    model = create_lstm_model(
        best_params,
        SEQ_LEN,
        NUM_FEATS,
        loss_fn     = LOSS_FUNCTION,
        huber_delta = HUBER_DELTA,
    )
    model.summary()

    train_gen = SequenceDataGenerator(
        X_train_seq, y_train_seq,
        batch_size=FINAL_BATCH_SIZE, shuffle=True, seed=RANDOM_SEED
    )
    val_gen = SequenceDataGenerator(
        X_val_seq, y_val_seq,
        batch_size=FINAL_BATCH_SIZE, shuffle=False
    )

    history = model.fit(
        train_gen,
        validation_data = val_gen,
        epochs          = FINAL_EPOCHS,
        callbacks       = [
            EarlyStopping(
                monitor='val_loss', patience=FINAL_PATIENCE,
                restore_best_weights=True, verbose=1,
            )
        ],
        verbose=1,
    )
    del train_gen, val_gen
    gc.collect()

    # ── 3g. Save model + config ──────────────────────────────────────────
    print('[3g] Saving model')
    model.save(os.path.join(exp_dir, 'model', f'NiOA_DRNN_k{HORIZON}.h5'))
    joblib.dump(scaler, os.path.join(exp_dir, 'scaler.pkl'))
    with open(os.path.join(exp_dir, 'training_config.json'), 'w') as _f:
        json.dump({
            'horizon_k'             : HORIZON,
            'sequence_length'       : SEQUENCE_LENGTH,
            'gap_tolerance'         : GAP_TOLERANCE_FACTOR,
            'target_cap_percentile' : TARGET_CAP_PERCENTILE,
            'log_transform'         : TARGET_LOG_TRANSFORM,
            'loss_function'         : LOSS_FUNCTION,
            'huber_delta'           : HUBER_DELTA,
            'train_ratio'           : TRAIN_RATIO,
            'val_ratio'             : VAL_RATIO,
            'random_seed'           : RANDOM_SEED,
            'final_batch_size'      : FINAL_BATCH_SIZE,
            'opt_subset_ratio'      : OPT_SUBSET_RATIO,
            'n_agents'              : N_AGENTS,
            'max_iterations'        : MAX_ITERATIONS,
            'final_epochs'          : FINAL_EPOCHS,
            'final_patience'        : FINAL_PATIENCE,
            'best_params'           : to_python_types(best_params),
            'best_nioa_loss'        : float(best_loss),
            'completed_at'          : datetime.now().isoformat(),
        }, _f, indent=4)

    # ── 3h. Evaluation ───────────────────────────────────────────────────
    # v2: pass log_transform=True so metrics are reported in original kWh
    print('[3h] Evaluating on test set')
    metrics_df, y_true, y_pred, _note = evaluate_keras_model(
        model, X_test_seq, y_test_seq,
        log_transform = TARGET_LOG_TRANSFORM,
    )
    metrics_dict = dict(zip(metrics_df['Metric'], metrics_df['Value']))
    print(metrics_df.to_string(index=False))

    # Save predictions in original kWh space (already inverted inside
    # evaluate_keras_model when log_transform=True)
    np.save(os.path.join(exp_dir, 'predictions', 'y_test_true.npy'), y_true)
    np.save(os.path.join(exp_dir, 'predictions', 'y_test_pred.npy'), y_pred)
    with open(os.path.join(exp_dir, 'metrics.json'), 'w') as _f:
        json.dump(metrics_dict, _f, indent=4)

    all_results[HORIZON] = {
        'metrics'    : metrics_dict,
        'exp_dir'    : exp_dir,
        'best_params': to_python_types(best_params),
        'best_loss'  : float(best_loss),
    }

    # ── 3i. Plots ────────────────────────────────────────────────────────
    print('[3i] Saving plots')
    _pd = os.path.join(exp_dir, 'plots')

    _fig, _ax = plt.subplots(figsize=(6, 6))
    _ax.scatter(y_true, y_pred, alpha=0.4, s=5, color='steelblue')
    _lim = [min(y_true.min(), y_pred.min()),
             max(y_true.max(), y_pred.max())]
    _ax.plot(_lim, _lim, 'r--', lw=1.5, label='Perfect prediction')
    _ax.set_xlabel(f'Actual ΔE  k={HORIZON}s (kWh)')
    _ax.set_ylabel(f'Predicted ΔE  k={HORIZON}s (kWh)')
    _ax.set_title(f'Predicted vs Actual  k={HORIZON}s')
    _ax.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(_pd, 'pred_vs_actual.png'), dpi=200)
    plt.close('all')

    _fig, _ax = plt.subplots(figsize=(7, 4))
    sns.histplot(y_true - y_pred, bins=60, kde=True, ax=_ax, color='steelblue')
    _ax.axvline(0, color='red', lw=1.2, linestyle='--')
    _ax.set_xlabel('Residual (kWh)')
    _ax.set_title(f'Residual Distribution  k={HORIZON}s')
    plt.tight_layout()
    plt.savefig(os.path.join(_pd, 'residuals.png'), dpi=200)
    plt.close('all')

    _fig, _ax = plt.subplots(figsize=(8, 4))
    _ax.plot(history.history['loss'],     lw=1.5, label='Train loss')
    _ax.plot(history.history['val_loss'], lw=1.5, label='Val loss')
    _ax.set_xlabel('Epoch');  _ax.set_ylabel(f'{LOSS_FUNCTION.upper()} loss')
    _ax.set_title(f'Training / Validation Loss  k={HORIZON}s')
    _ax.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(_pd, 'training_curve.png'), dpi=200)
    plt.close('all')

    _fig, _ax = plt.subplots(figsize=(7, 4))
    _ax.plot(convergence, marker='o', lw=2, color='darkorange', ms=6)
    _ax.set_xlabel('Iteration  (0 = initial population)')
    _ax.set_ylabel('Best validation loss')
    _ax.set_title(f'NiOA Convergence  k={HORIZON}s')
    plt.tight_layout()
    plt.savefig(os.path.join(_pd, 'nioa_convergence.png'), dpi=200)
    plt.close('all')

    _ns = min(500, len(y_true))
    _fig, _ax = plt.subplots(figsize=(12, 4))
    _ax.plot(y_true[:_ns], lw=1.0, alpha=0.9, label='Actual')
    _ax.plot(y_pred[:_ns], lw=1.0, alpha=0.75,
             linestyle='--', label='Predicted')
    _ax.set_xlabel('Test sample index')
    _ax.set_ylabel(f'ΔE  k={HORIZON}s (kWh)')
    _ax.set_title(f'First {_ns} test samples  k={HORIZON}s')
    _ax.legend()
    plt.tight_layout()
    plt.savefig(os.path.join(_pd, 'time_series_overlay.png'), dpi=200)
    plt.close('all')

    print(f'  5 plots → {_pd}')

    _total_h = (time.time() - loop_start) / 3600
    print(f'\n  DONE k={HORIZON}s  '
      f'MAE={metrics_dict["MAE"]:.4f} kWh  '
      f'RMSE={metrics_dict["RMSE"]:.4f} kWh  '
      f'R2={metrics_dict["R2"]:.4f}  '
      f'[{_total_h:.2f} h total]')
    print('=' * 65)

    del (model, history, X_train_seq, y_train_seq,
         X_val_seq, y_val_seq, X_test_seq, y_test_seq,
         y_true, y_pred, scaler, best_params, convergence)
    K.clear_session()
    gc.collect()

_total_h = (time.time() - loop_start) / 3600
# Out:
# \n=================================================================
#   Horizon 1/4 : k = 60 s   14:41:27   0.00 h elapsed
# =================================================================
# \n[3a] Preprocessing  (k=60s, gap=2.0x, cap=99.5th pctile, log1p=True)
#   Target capped at 99.5th pctile = 417.2420 kWh
#   log1p transform applied  (new range: 0.0000 to 6.0361)
#
# ==============================================================
#   Preprocessing summary  (k = 60 s, tolerance = 2.0x)
# ==============================================================
#   Rows in raw CSV          :  3,178,051
#   Gap-corrupted targets    :     10,454  (elapsed > 120 s)
#   Counter-reset targets    :    152,859  (delta_E < 0)
#   Dropped for NaN          :    163,314
#   Removed by Z-score       :    336,462  (features only)
#   Capped at 99.5th pctile :          0  (cap = 417.2420 kWh)
#   log1p transform applied  :        yes
#   Final usable rows        :  2,678,196
#
#   Target  energy_delta_k  [log1p(kWh)]:
#     mean  =     0.097706
#     std   =     0.755153
#     min   =     0.000000
#     max   =     6.036060
# ==============================================================
#
# [3b] Splitting
#   train 1,874,737  val   401,729  test   401,730  — no leakage
# [3c] Scaling + sequence generation
#   features (17): ['weekday', 'voltage', 'current', 'power', 'frequency', 'power_factor', 'sensor_temperature', 'cpu_usage_percent', 'WORKSTATION_CPU_POWER', 'WORKSTATION_CPU_TEMP', 'WORKSTATION_GPU', 'WORKSTATION_GPU_POWER', 'WORKSTATION_GPU_TEMP', 'WORKSTATION_RAM', 'ram_power_watts', 'hour', 'voltage_lag1']
#   X_train (1874617, 120, 17)  X_val (401609, 120, 17)  X_test (401610, 120, 17)
#   RAM (train seq) ≈ 15.30 GB   GPU per batch ≈ 0.1 MB
# [3d] Saving canonical splits
#   splits → D:\pipeline5_2\results\splits\horizon_60
# [3e] NiOA optimisation  (agents=6  iter=6  subset=30%  limit=1800s/trial  loss=huber)
# Starting Ninja Optimisation Algorithm...
#
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
# Iteration 1/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000702
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 64
#     dropout: 0.3061753482887407
#     optimizer: adamw
#     learning_rate: 0.000466530301221283
#     batch_size: 32
#
# Iteration 2/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000702
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 64
#     dropout: 0.3061753482887407
#     optimizer: adamw
#     learning_rate: 0.000466530301221283
#     batch_size: 32
#
# Iteration 3/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000702
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 64
#     dropout: 0.3061753482887407
#     optimizer: adamw
#     learning_rate: 0.000466530301221283
#     batch_size: 32
#
# Iteration 4/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000702
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 64
#     dropout: 0.3061753482887407
#     optimizer: adamw
#     learning_rate: 0.000466530301221283
#     batch_size: 32
#
# Iteration 5/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#   Best validation loss so far : 0.00000702
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 64
#     dropout: 0.3061753482887407
#     optimizer: adamw
#     learning_rate: 0.000466530301221283
#     batch_size: 32
#
# Iteration 6/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000702
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 64
#     dropout: 0.3061753482887407
#     optimizer: adamw
#     learning_rate: 0.000466530301221283
#     batch_size: 32
#
# Optimisation completed in 23.46 hours
#   Best NiOA val loss : 0.00000702
#   Best params : {'lstm_layers': 3, 'units': 64, 'dropout': 0.3061753482887407, 'optimizer': 'adamw', 'learning_rate': 0.000466530301221283, 'batch_size': 32}
# [3f] Final training  (batch=16  epochs=40  patience=7  loss=huber)
# Model: "NiOA_DRNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 120, 128)         41984
#  l)
#
#  lstm_1 (LSTM)               (None, 120, 64)           49408
#
#  dropout (Dropout)           (None, 120, 64)           0
#
#  lstm_2 (LSTM)               (None, 120, 64)           33024
#
#  dropout_1 (Dropout)         (None, 120, 64)           0
#
#  batch_normalization (BatchN  (None, 120, 64)          256
#  ormalization)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 25)                1625
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 130,483
# Trainable params: 130,355
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/40
# 117163/117163 [==============================] - 8478s 72ms/step - loss: 1.0369e-04 - mae: 0.0036 - val_loss: 6.6753e-06 - val_mae: 0.0024
# Epoch 2/40
# 117163/117163 [==============================] - 2807s 24ms/step - loss: 7.8542e-06 - mae: 0.0030 - val_loss: 6.6988e-06 - val_mae: 0.0030
# Epoch 3/40
# 117163/117163 [==============================] - 2811s 24ms/step - loss: 7.8554e-06 - mae: 0.0030 - val_loss: 7.0135e-06 - val_mae: 0.0033
# Epoch 4/40
# 117163/117163 [==============================] - 3182s 27ms/step - loss: 7.8553e-06 - mae: 0.0030 - val_loss: 6.6443e-06 - val_mae: 0.0024
# Epoch 5/40
# 117163/117163 [==============================] - 3545s 30ms/step - loss: 7.8564e-06 - mae: 0.0030 - val_loss: 6.7426e-06 - val_mae: 0.0030
# Epoch 6/40
# 117163/117163 [==============================] - 3542s 30ms/step - loss: 7.8567e-06 - mae: 0.0030 - val_loss: 6.6818e-06 - val_mae: 0.0029
# Epoch 7/40
# 117163/117163 [==============================] - 3542s 30ms/step - loss: 7.8553e-06 - mae: 0.0030 - val_loss: 6.5919e-06 - val_mae: 0.0027
# Epoch 8/40
# 117163/117163 [==============================] - 3540s 30ms/step - loss: 7.8576e-06 - mae: 0.0030 - val_loss: 6.6136e-06 - val_mae: 0.0028
# Epoch 9/40
# 117163/117163 [==============================] - 3546s 30ms/step - loss: 7.8566e-06 - mae: 0.0030 - val_loss: 6.8370e-06 - val_mae: 0.0031
# Epoch 10/40
# 117163/117163 [==============================] - 3551s 30ms/step - loss: 7.8557e-06 - mae: 0.0030 - val_loss: 6.5910e-06 - val_mae: 0.0027
# Epoch 11/40
# 117163/117163 [==============================] - 3546s 30ms/step - loss: 7.8577e-06 - mae: 0.0030 - val_loss: 6.5893e-06 - val_mae: 0.0026
# Epoch 12/40
# 117163/117163 [==============================] - 3545s 30ms/step - loss: 7.8572e-06 - mae: 0.0030 - val_loss: 6.9986e-06 - val_mae: 0.0033
# Epoch 13/40
# 117163/117163 [==============================] - 3549s 30ms/step - loss: 7.8574e-06 - mae: 0.0030 - val_loss: 6.5915e-06 - val_mae: 0.0026
# Epoch 14/40
# 117163/117163 [==============================] - 3551s 30ms/step - loss: 7.8579e-06 - mae: 0.0030 - val_loss: 6.5928e-06 - val_mae: 0.0026
# Epoch 15/40
# 117163/117163 [==============================] - 3551s 30ms/step - loss: 7.8556e-06 - mae: 0.0030 - val_loss: 7.2879e-06 - val_mae: 0.0035
# Epoch 16/40
# 117163/117163 [==============================] - 3550s 30ms/step - loss: 7.8576e-06 - mae: 0.0030 - val_loss: 6.6083e-06 - val_mae: 0.0028
# Epoch 17/40
# 117163/117163 [==============================] - 3553s 30ms/step - loss: 7.8584e-06 - mae: 0.0030 - val_loss: 6.6638e-06 - val_mae: 0.0029
# Epoch 18/40
# 117161/117163 [============================>.] - ETA: 0s - loss: 7.8576e-06 - mae: 0.0030Restoring model weights from the end of the best epoch: 11.
# 117163/117163 [==============================] - 3541s 30ms/step - loss: 7.8576e-06 - mae: 0.0030 - val_loss: 7.1055e-06 - val_mae: 0.0033
# Epoch 18: early stopping
# [3g] Saving model
# WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# [3h] Evaluating on test set
# Metric      Value
#    MAE  44.259638
#   RMSE 135.847824
#     R2  -0.118744
#  sMAPE 107.235549
# [3i] Saving plots
#   5 plots → D:\pipeline5_2\results\nioa_drnn\k60_seq120_20260408_141156\plots
#
#   DONE k=60s  MAE=44.2596 kWh  RMSE=135.8478 kWh  R2=-0.1187  [42.16 h total]
# =================================================================
# \n=================================================================
#   Horizon 2/4 : k = 300 s   08:51:43   42.17 h elapsed
# =================================================================
# \n[3a] Preprocessing  (k=300s, gap=2.0x, cap=99.5th pctile, log1p=True)
#   Target capped at 99.5th pctile = 417.4370 kWh
#   log1p transform applied  (new range: 0.0000 to 6.0365)
#
# ==============================================================
#   Preprocessing summary  (k = 300 s, tolerance = 2.0x)
# ==============================================================
#   Rows in raw CSV          :  3,178,051
#   Gap-corrupted targets    :     13,070  (elapsed > 600 s)
#   Counter-reset targets    :    170,459  (delta_E < 0)
#   Dropped for NaN          :    183,530
#   Removed by Z-score       :    318,056  (features only)
#   Capped at 99.5th pctile :          0  (cap = 417.4370 kWh)
#   log1p transform applied  :        yes
#   Final usable rows        :  2,676,386
#
#   Target  energy_delta_k  [log1p(kWh)]:
#     mean  =     0.147769
#     std   =     0.905889
#     min   =     0.000000
#     max   =     6.036526
# ==============================================================
#
# [3b] Splitting
#   train 1,873,470  val   401,458  test   401,458  — no leakage
# [3c] Scaling + sequence generation
#   features (17): ['weekday', 'voltage', 'current', 'power', 'frequency', 'power_factor', 'sensor_temperature', 'cpu_usage_percent', 'WORKSTATION_CPU_POWER', 'WORKSTATION_CPU_TEMP', 'WORKSTATION_GPU', 'WORKSTATION_GPU_POWER', 'WORKSTATION_GPU_TEMP', 'WORKSTATION_RAM', 'ram_power_watts', 'hour', 'voltage_lag1']
#   X_train (1873350, 120, 17)  X_val (401338, 120, 17)  X_test (401338, 120, 17)
#   RAM (train seq) ≈ 15.29 GB   GPU per batch ≈ 0.1 MB
# [3d] Saving canonical splits
#   splits → D:\pipeline5_2\results\splits\horizon_300
# [3e] NiOA optimisation  (agents=6  iter=6  subset=30%  limit=1800s/trial  loss=huber)
# Starting Ninja Optimisation Algorithm...
#
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
# Iteration 1/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#   Best validation loss so far : 0.00000748
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 64
#     dropout: 0.30542260908465624
#     optimizer: adamw
#     learning_rate: 0.00015590631960773755
#     batch_size: 32
#
# Iteration 2/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000716
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.3963541463707538
#     optimizer: adamw
#     learning_rate: 0.00017517851337039888
#     batch_size: 32
#
# Iteration 3/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000716
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.3963541463707538
#     optimizer: adamw
#     learning_rate: 0.00017517851337039888
#     batch_size: 32
#
# Iteration 4/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000716
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.3963541463707538
#     optimizer: adamw
#     learning_rate: 0.00017517851337039888
#     batch_size: 32
#
# Iteration 5/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000709
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.3963541463707538
#     optimizer: adamw
#     learning_rate: 0.00017517851337039888
#     batch_size: 32
#
# Iteration 6/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 6.
#   Best validation loss so far : 0.00000709
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.3963541463707538
#     optimizer: adamw
#     learning_rate: 0.00017517851337039888
#     batch_size: 32
#
# Optimisation completed in 23.21 hours
#   Best NiOA val loss : 0.00000709
#   Best params : {'lstm_layers': 2, 'units': 64, 'dropout': 0.3963541463707538, 'optimizer': 'adamw', 'learning_rate': 0.00017517851337039888, 'batch_size': 32}
# [3f] Final training  (batch=16  epochs=40  patience=7  loss=huber)
# Model: "NiOA_DRNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 120, 128)         41984
#  l)
#
#  lstm_1 (LSTM)               (None, 120, 64)           49408
#
#  dropout (Dropout)           (None, 120, 64)           0
#
#  batch_normalization (BatchN  (None, 120, 64)          256
#  ormalization)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 25)                1625
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 97,459
# Trainable params: 97,331
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/40
# 117084/117084 [==============================] - 9854s 84ms/step - loss: 1.3036e-04 - mae: 0.0031 - val_loss: 8.7344e-06 - val_mae: 0.0037
# Epoch 2/40
# 117084/117084 [==============================] - 2301s 20ms/step - loss: 6.3785e-06 - mae: 0.0019 - val_loss: 9.0350e-06 - val_mae: 0.0038
# Epoch 3/40
# 117084/117084 [==============================] - 2253s 19ms/step - loss: 6.3306e-06 - mae: 0.0019 - val_loss: 9.1351e-06 - val_mae: 0.0038
# Epoch 4/40
# 117084/117084 [==============================] - 2231s 19ms/step - loss: 6.3252e-06 - mae: 0.0019 - val_loss: 8.8791e-06 - val_mae: 0.0038
# Epoch 5/40
# 117084/117084 [==============================] - 2221s 19ms/step - loss: 6.3210e-06 - mae: 0.0019 - val_loss: 8.8368e-06 - val_mae: 0.0037
# Epoch 6/40
# 117084/117084 [==============================] - 2215s 19ms/step - loss: 6.3103e-06 - mae: 0.0019 - val_loss: 8.6273e-06 - val_mae: 0.0035
# Epoch 7/40
# 117084/117084 [==============================] - 2208s 19ms/step - loss: 6.3008e-06 - mae: 0.0019 - val_loss: 8.7214e-06 - val_mae: 0.0034
# Epoch 8/40
# 117084/117084 [==============================] - 2219s 19ms/step - loss: 6.2852e-06 - mae: 0.0019 - val_loss: 9.0977e-06 - val_mae: 0.0035
# Epoch 9/40
# 117084/117084 [==============================] - 2210s 19ms/step - loss: 6.2773e-06 - mae: 0.0019 - val_loss: 9.4385e-06 - val_mae: 0.0037
# Epoch 10/40
# 117084/117084 [==============================] - 2213s 19ms/step - loss: 6.2674e-06 - mae: 0.0019 - val_loss: 1.1538e-05 - val_mae: 0.0046
# Epoch 11/40
# 117084/117084 [==============================] - 2380s 20ms/step - loss: 6.2590e-06 - mae: 0.0019 - val_loss: 1.0705e-05 - val_mae: 0.0041
# Epoch 12/40
# 117084/117084 [==============================] - 2604s 22ms/step - loss: 6.2458e-06 - mae: 0.0019 - val_loss: 1.0644e-05 - val_mae: 0.0037
# Epoch 13/40
# 117083/117084 [============================>.] - ETA: 0s - loss: 6.2314e-06 - mae: 0.0019Restoring model weights from the end of the best epoch: 6.
# 117084/117084 [==============================] - 2591s 22ms/step - loss: 6.2314e-06 - mae: 0.0019 - val_loss: 1.2404e-05 - val_mae: 0.0041
# Epoch 13: early stopping
# [3g] Saving model
# WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# [3h] Evaluating on test set
# Metric      Value
#    MAE  64.313438
#   RMSE 163.768289
#     R2  -0.182317
#  sMAPE  76.860922
# [3i] Saving plots
# C:\Users\AnweshaSingh\AppData\Local\Temp\ipykernel_9444\3475257809.py:287: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
#   5 plots → D:\pipeline5_2\results\nioa_drnn\k300_seq120_20260410_080632\plots
#
#   DONE k=300s  MAE=64.3134 kWh  RMSE=163.7683 kWh  R2=-0.1823  [75.97 h total]
# =================================================================
# \n=================================================================
#   Horizon 3/4 : k = 900 s   18:40:43   75.99 h elapsed
# =================================================================
# \n[3a] Preprocessing  (k=900s, gap=2.0x, cap=99.5th pctile, log1p=True)
#   Target capped at 99.5th pctile = 417.4730 kWh
#   log1p transform applied  (new range: 0.0080 to 6.0366)
#
# ==============================================================
#   Preprocessing summary  (k = 900 s, tolerance = 2.0x)
# ==============================================================
#   Rows in raw CSV          :  3,178,051
#   Gap-corrupted targets    :     22,705  (elapsed > 1800 s)
#   Counter-reset targets    :    125,942  (delta_E < 0)
#   Dropped for NaN          :    148,648
#   Removed by Z-score       :    353,682  (features only)
#   Capped at 99.5th pctile :          0  (cap = 417.4730 kWh)
#   log1p transform applied  :        yes
#   Final usable rows        :  2,675,642
#
#   Target  energy_delta_k  [log1p(kWh)]:
#     mean  =     0.170155
#     std   =     0.922591
#     min   =     0.007968
#     max   =     6.036612
# ==============================================================
#
# [3b] Splitting
#   train 1,872,949  val   401,346  test   401,347  — no leakage
# [3c] Scaling + sequence generation
#   features (17): ['weekday', 'voltage', 'current', 'power', 'frequency', 'power_factor', 'sensor_temperature', 'cpu_usage_percent', 'WORKSTATION_CPU_POWER', 'WORKSTATION_CPU_TEMP', 'WORKSTATION_GPU', 'WORKSTATION_GPU_POWER', 'WORKSTATION_GPU_TEMP', 'WORKSTATION_RAM', 'ram_power_watts', 'hour', 'voltage_lag1']
#   X_train (1872829, 120, 17)  X_val (401226, 120, 17)  X_test (401227, 120, 17)
#   RAM (train seq) ≈ 15.28 GB   GPU per batch ≈ 0.1 MB
# [3d] Saving canonical splits
#   splits → D:\pipeline5_2\results\splits\horizon_900
# [3e] NiOA optimisation  (agents=6  iter=6  subset=30%  limit=1800s/trial  loss=huber)
# Starting Ninja Optimisation Algorithm...
#
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 1.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 2.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
# Iteration 1/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#   Best validation loss so far : 0.00000834
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.4616964037668108
#     optimizer: adamw
#     learning_rate: 0.0004386885315274072
#     batch_size: 32
#
# Iteration 2/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#   Best validation loss so far : 0.00000834
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.4616964037668108
#     optimizer: adamw
#     learning_rate: 0.0004386885315274072
#     batch_size: 32
#
# Iteration 3/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#   Best validation loss so far : 0.00000834
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.4616964037668108
#     optimizer: adamw
#     learning_rate: 0.0004386885315274072
#     batch_size: 32
#
# Iteration 4/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#   Best validation loss so far : 0.00000807
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.4386087035371217
#     optimizer: adamw
#     learning_rate: 0.000229192698127955
#     batch_size: 32
#
# Iteration 5/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 2.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 1.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 1.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 1.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 1.
#   Best validation loss so far : 0.00000807
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.4386087035371217
#     optimizer: adamw
#     learning_rate: 0.000229192698127955
#     batch_size: 32
#
# Iteration 6/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 2.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#   Best validation loss so far : 0.00000807
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 64
#     dropout: 0.4386087035371217
#     optimizer: adamw
#     learning_rate: 0.000229192698127955
#     batch_size: 32
#
# Optimisation completed in 26.66 hours
#   Best NiOA val loss : 0.00000807
#   Best params : {'lstm_layers': 2, 'units': 64, 'dropout': 0.4386087035371217, 'optimizer': 'adamw', 'learning_rate': 0.000229192698127955, 'batch_size': 32}
# [3f] Final training  (batch=16  epochs=40  patience=7  loss=huber)
# Model: "NiOA_DRNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 120, 128)         41984
#  l)
#
#  lstm_1 (LSTM)               (None, 120, 64)           49408
#
#  dropout (Dropout)           (None, 120, 64)           0
#
#  batch_normalization (BatchN  (None, 120, 64)          256
#  ormalization)
#
#  global_max_pooling1d (Globa  (None, 64)               0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 64)                4160
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 25)                1625
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 97,459
# Trainable params: 97,331
# Non-trainable params: 128
# _________________________________________________________________
# Epoch 1/40
# 117051/117051 [==============================] - 11161s 95ms/step - loss: 2.1327e-04 - mae: 0.0042 - val_loss: 1.4693e-05 - val_mae: 0.0032
# Epoch 2/40
# 117051/117051 [==============================] - 2724s 23ms/step - loss: 8.7068e-06 - mae: 0.0023 - val_loss: 1.3261e-05 - val_mae: 0.0035
# Epoch 3/40
# 117051/117051 [==============================] - 2595s 22ms/step - loss: 7.8592e-06 - mae: 0.0021 - val_loss: 1.0965e-05 - val_mae: 0.0039
# Epoch 4/40
# 117051/117051 [==============================] - 2556s 22ms/step - loss: 6.7141e-06 - mae: 0.0018 - val_loss: 1.0972e-05 - val_mae: 0.0040
# Epoch 5/40
# 117051/117051 [==============================] - 2540s 22ms/step - loss: 6.1518e-06 - mae: 0.0017 - val_loss: 1.1691e-05 - val_mae: 0.0044
# Epoch 6/40
# 117051/117051 [==============================] - 2544s 22ms/step - loss: 6.0221e-06 - mae: 0.0018 - val_loss: 1.6454e-05 - val_mae: 0.0050
# Epoch 7/40
# 117051/117051 [==============================] - 2555s 22ms/step - loss: 5.9139e-06 - mae: 0.0018 - val_loss: 2.9439e-05 - val_mae: 0.0063
# Epoch 8/40
# 117051/117051 [==============================] - 2554s 22ms/step - loss: 5.8603e-06 - mae: 0.0018 - val_loss: 2.1433e-05 - val_mae: 0.0056
# Epoch 9/40
# 117051/117051 [==============================] - 2543s 22ms/step - loss: 5.8079e-06 - mae: 0.0017 - val_loss: 2.1509e-05 - val_mae: 0.0056
# Epoch 10/40
# 117051/117051 [==============================] - ETA: 0s - loss: 5.7739e-06 - mae: 0.0017Restoring model weights from the end of the best epoch: 3.
# 117051/117051 [==============================] - 2551s 22ms/step - loss: 5.7739e-06 - mae: 0.0017 - val_loss: 1.6385e-05 - val_mae: 0.0051
# Epoch 10: early stopping
# [3g] Saving model
# WARNING:tensorflow:HDF5 format does not save weights of `optimizer_experimental.Optimizer`, your optimizer will be recompiled at loading time.
# [3h] Evaluating on test set
# Metric      Value
#    MAE  67.146487
#   RMSE 167.333921
#     R2  -0.191877
#  sMAPE  61.022334
# [3i] Saving plots
# C:\Users\AnweshaSingh\AppData\Local\Temp\ipykernel_9444\3475257809.py:287: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   plt.tight_layout()
#   5 plots → D:\pipeline5_2\results\nioa_drnn\k900_seq120_20260411_212307\plots
#
#   DONE k=900s  MAE=67.1465 kWh  RMSE=167.3339 kWh  R2=-0.1919  [112.31 h total]
# =================================================================
# \n=================================================================
#   Horizon 4/4 : k = 1800 s   07:00:50   112.32 h elapsed
# =================================================================
# \n[3a] Preprocessing  (k=1800s, gap=2.0x, cap=99.5th pctile, log1p=True)
#   Target capped at 99.5th pctile = 417.5200 kWh
#   log1p transform applied  (new range: 0.0159 to 6.0367)
#
# ==============================================================
#   Preprocessing summary  (k = 1800 s, tolerance = 2.0x)
# ==============================================================
#   Rows in raw CSV          :  3,178,051
#   Gap-corrupted targets    :     35,678  (elapsed > 3600 s)
#   Counter-reset targets    :    138,434  (delta_E < 0)
#   Dropped for NaN          :    174,113
#   Removed by Z-score       :    349,054  (features only)
#   Capped at 99.5th pctile :          0  (cap = 417.5200 kWh)
#   log1p transform applied  :        yes
#   Final usable rows        :  2,654,805
#
#   Target  energy_delta_k  [log1p(kWh)]:
#     mean  =     0.206245
#     std   =     0.955549
#     min   =     0.015873
#     max   =     6.036725
# ==============================================================
#
# [3b] Splitting
#   train 1,858,363  val   398,221  test   398,221  — no leakage
# [3c] Scaling + sequence generation
#   features (17): ['weekday', 'voltage', 'current', 'power', 'frequency', 'power_factor', 'sensor_temperature', 'cpu_usage_percent', 'WORKSTATION_CPU_POWER', 'WORKSTATION_CPU_TEMP', 'WORKSTATION_GPU', 'WORKSTATION_GPU_POWER', 'WORKSTATION_GPU_TEMP', 'WORKSTATION_RAM', 'ram_power_watts', 'hour', 'voltage_lag1']
#   X_train (1858243, 120, 17)  X_val (398101, 120, 17)  X_test (398101, 120, 17)
#   RAM (train seq) ≈ 15.16 GB   GPU per batch ≈ 0.1 MB
# [3d] Saving canonical splits
#   splits → D:\pipeline5_2\results\splits\horizon_1800
# [3e] NiOA optimisation  (agents=6  iter=6  subset=30%  limit=1800s/trial  loss=huber)
# Starting Ninja Optimisation Algorithm...
#
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 1.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 2.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 2.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 2.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 2.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
# Iteration 1/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#   Best validation loss so far : 0.00001609
#   Best hyperparameters so far :
#     lstm_layers: 2
#     units: 128
#     dropout: 0.37403589142749893
#     optimizer: adamw
#     learning_rate: 0.0001531477436182984
#     batch_size: 32
#
# Iteration 2/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#   Best validation loss so far : 0.00000951
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 128
#     dropout: 0.44816957368195837
#     optimizer: adamw
#     learning_rate: 0.0003308383908988408
#     batch_size: 32
#
# Iteration 3/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#   Best validation loss so far : 0.00000951
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 128
#     dropout: 0.44816957368195837
#     optimizer: adamw
#     learning_rate: 0.0003308383908988408
#     batch_size: 32
#
# Iteration 4/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 5.
#   Best validation loss so far : 0.00000951
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 128
#     dropout: 0.44816957368195837
#     optimizer: adamw
#     learning_rate: 0.0003308383908988408
#     batch_size: 32
#
# Iteration 5/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#   Best validation loss so far : 0.00000951
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 128
#     dropout: 0.44816957368195837
#     optimizer: adamw
#     learning_rate: 0.0003308383908988408
#     batch_size: 32
#
# Iteration 6/6
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 4.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#
#   [TimeLimitCallback] 1800s limit reached — stopping trial at epoch 3.
#   Best validation loss so far : 0.00000951
#   Best hyperparameters so far :
#     lstm_layers: 3
#     units: 128
#     dropout: 0.44816957368195837
#     optimizer: adamw
#     learning_rate: 0.0003308383908988408
#     batch_size: 32
#
# Optimisation completed in 23.80 hours
#   Best NiOA val loss : 0.00000951
#   Best params : {'lstm_layers': 3, 'units': 128, 'dropout': 0.44816957368195837, 'optimizer': 'adamw', 'learning_rate': 0.0003308383908988408, 'batch_size': 32}
# [3f] Final training  (batch=16  epochs=40  patience=7  loss=huber)
# Model: "NiOA_DRNN"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  bidirectional (Bidirectiona  (None, 120, 256)         149504
#  l)
#
#  lstm_1 (LSTM)               (None, 120, 128)          197120
#
#  dropout (Dropout)           (None, 120, 128)          0
#
#  lstm_2 (LSTM)               (None, 120, 128)          131584
#
#  dropout_1 (Dropout)         (None, 120, 128)          0
#
#  batch_normalization (BatchN  (None, 120, 128)         512
#  ormalization)
#
#  global_max_pooling1d (Globa  (None, 128)              0
#  lMaxPooling1D)
#
#  dense (Dense)               (None, 64)                8256
#
#  dropout_2 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 25)                1625
#
#  dense_2 (Dense)             (None, 1)                 26
#
# =================================================================
# Total params: 488,627
# Trainable params: 488,371
# Non-trainable params: 256
# _________________________________________________________________
# Epoch 1/40
# 116140/116140 [==============================] - 9778s 84ms/step - loss: 1.7342e-04 - mae: 0.0062 - val_loss: 5.1316e-05 - val_mae: 0.0089
# Epoch 2/40
# 116140/116140 [==============================] - 4436s 38ms/step - loss: 2.9272e-05 - mae: 0.0050 - val_loss: 5.9313e-05 - val_mae: 0.0096
# Epoch 3/40
# 116140/116140 [==============================] - 3843s 33ms/step - loss: 3.2932e-05 - mae: 0.0056 - val_loss: 5.8863e-05 - val_mae: 0.0096
# Epoch 4/40
# 116140/116140 [==============================] - 3493s 30ms/step - loss: 2.2342e-05 - mae: 0.0041 - val_loss: 5.4252e-05 - val_mae: 0.0092
# Epoch 5/40
# 111717/116140 [===========================>..] - ETA: 1:56 - loss: 1.1084e-05 - mae: 0.0026
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# Cell In[3], line 208
#     199 train_gen = SequenceDataGenerator(
#     200     X_train_seq, y_train_seq,
#     201     batch_size=FINAL_BATCH_SIZE, shuffle=True, seed=RANDOM_SEED
#     202 )
#     203 val_gen = SequenceDataGenerator(
#     204     X_val_seq, y_val_seq,
#     205     batch_size=FINAL_BATCH_SIZE, shuffle=False
#     206 )
# --> 208 history = model.fit(
#     209     train_gen,
#     210     validation_data = val_gen,
#     211     epochs          = FINAL_EPOCHS,
#     212     callbacks       = [
#     213         EarlyStopping(
#     214             monitor='val_loss', patience=FINAL_PATIENCE,
#     215             restore_best_weights=True, verbose=1,
#     216         )
#     217     ],
#     218     verbose=1,
#     219 )
#     220 del train_gen, val_gen
#     221 gc.collect()
#
# File ~\.conda\envs\AshCEP\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\.conda\envs\AshCEP\lib\site-packages\tensorflow\python\eager\execute.py:54, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      52 try:
#      53   ctx.ensure_initialized()
# ---> 54   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      55                                       inputs, attrs, num_outputs)
#      56 except core._NotOkStatusException as e:
#      57   if name is not None:
#
# InternalError: Graph execution error:
#
# Failed to call ThenRnnBackward with model config: [rnn_mode, rnn_input_mode, rnn_direction_mode]: 2, 0, 0 , [num_layers, input_size, num_units, dir_count, max_seq_length, batch_size, cell_num_units]: [1, 17, 128, 1, 120, 16, 128]
# 	 [[{{node gradients/CudnnRNN_grad/CudnnRNNBackprop}}]]
# 	 [[PartitionedCall_3]] [Op:__inference_train_function_87276142]

# %%
print(_total_h)

# %% [markdown]
# ## Cell 4 — Cross-Horizon Summary
# Run after Cell 3 completes.

# %%
if not all_results:
    print('No results yet — run Cell 3 first.')
else:
    _rows = [
        {
            'Horizon_k_s'   : _hk,
            'MAE'           : _r['metrics']['MAE'],
            'RMSE'          : _r['metrics']['RMSE'],
            'R2'            : _r['metrics']['R2'],
            'sMAPE'         : _r['metrics']['sMAPE'],
            'NiOA_best_MSE' : _r['best_loss'],
            'exp_dir'       : os.path.basename(_r['exp_dir']),
        }
        for _hk, _r in sorted(all_results.items())
    ]
    summary = pd.DataFrame(_rows)

    print('NiOA-DRNN — all trained horizons')
    print('=' * 72)
    print(summary.to_string(index=False, float_format='{:.6f}'.format))
    print('=' * 72)

    _csv = os.path.join(ANALYSIS_DIR, 'nioa_drnn_all_horizons.csv')
    summary.to_csv(_csv, index=False)
    print(f'\nCSV  → {_csv}')

    # MAE bar chart
    _fig, _ax = plt.subplots(figsize=(8, 4))
    _ax.bar(
        [f'{r["Horizon_k_s"]}s' for r in _rows],
        [r['MAE'] for r in _rows],
        color='steelblue', edgecolor='white',
    )
    _ax.set_xlabel('Forecast horizon k')
    _ax.set_ylabel('MAE (kWh)')
    _ax.set_title('NiOA-DRNN — MAE per horizon')
    plt.tight_layout()
    _bar = os.path.join(ANALYSIS_DIR, 'nioa_mae_per_horizon.png')
    plt.savefig(_bar, dpi=200)
    plt.close('all')
    print(f'Plot → {_bar}')
