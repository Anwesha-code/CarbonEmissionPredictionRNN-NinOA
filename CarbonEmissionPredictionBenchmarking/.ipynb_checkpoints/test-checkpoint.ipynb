# %%
import tensorflow as tf
print("TF:", tf.__version__)

import numpy as np
import pandas as pd
print("All good")
# Out:
# C:\Users\Dell\anaconda3\envs\AshCEP\lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (1.26.20) or chardet (7.2.0)/charset_normalizer (None) doesn't match a supported version!
#   warnings.warn(
# TF: 2.21.0
# All good
